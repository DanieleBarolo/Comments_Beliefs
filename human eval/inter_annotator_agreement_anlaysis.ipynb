# %%
import pandas as pd

# %%
path = "test_gold_data"
results_df_first = pd.read_excel(f"{path}/insert_data_annotator_1.xlsx")
results_df_first
# Out:
#     provider_name  article_id  comment_id  \
# 0     motherjones  5392511582  3059057400
# 1     motherjones  5392511582  3059084937
# 2     motherjones  5392511582  3059098451
# 3     motherjones  5392511582  3059108161
# 4     motherjones  5392511582  3059121940
# ..            ...         ...         ...
# 202     breitbart  9638510923  6150719826
# 203     breitbart  9638510923  6150839685
# 204     breitbart  9638510923  6150849854
# 205     breitbart  9638510923  6150948423
# 206     breitbart  9638510923  6150949769
#
#                                                  Notes Barack Obama  \
# 0                                                  NaN          NaN
# 1    Here is refering to war (against Libya) not su...          NaN
# 2    This is hard as well. The guy is "advocating" ...          NaN
# 3    this is an answer to a deleted comment. Hard w...          NaN
# 4    this is an answer to a deleted comment. Still ...          NaN
# ...

# %%
results_df_second = pd.read_excel(f"{path}/insert_data_annotator_2.xlsx")
results_df_second
# Out:
#     provider_name  article_id  comment_id  \
# 0     motherjones  5392511582  3059057400
# 1     motherjones  5392511582  3059084937
# 2     motherjones  5392511582  3059098451
# 3     motherjones  5392511582  3059108161
# 4     motherjones  5392511582  3059121940
# ..            ...         ...         ...
# 202     breitbart  8263361810  5137572709
# 203     breitbart  8263361810  5137618011
# 204     breitbart  8263361810  5137666008
# 205     breitbart  8263361810  5137736031
# 206     breitbart  8263361810  5137793129
#
#                                                  Notes Barack Obama  \
# 0    America in decline is difficult to rate. What ...          NaN
# 1                                                  NaN          NaN
# 2                  sarcasm? Or am I missing something?          NaN
# 3                                                  NaN          NaN
# 4    Not really universal healthcare or unenpl bene...          NaN
# ...

# %%
master_assignements_df = pd.read_csv("comment_assignments_master.csv")
master_assignements_df
# Out:
#      article_id  comment_id    user_id  provider provider_name annotator_pair  \
# 0    5392511582  3068652864     617031         4   motherjones         (1, 2)
# 1    5392511582  3060312757  183440977         4   motherjones         (1, 2)
# 2    5392511582  3059121940   15651552         4   motherjones         (1, 2)
# 3    5392511582  3061231944  235747564         4   motherjones         (1, 2)
# 4    5392511582  3066560379   35998968         4   motherjones         (1, 2)
# ..          ...         ...        ...       ...           ...            ...
# 409  6141968269  3517227720     562780         1     breitbart         (3, 4)
# 410  6141968269  3517128881  132203087         1     breitbart         (3, 4)
# 411  6141968269  3517323856  146099024         1     breitbart         (3, 4)
# 412  6141968269  3517179837   60911793         1     breitbart         (3, 4)
# 413  6141968269  3524535857    6386548         1     breitbart         (3, 4)
#
#      annotator_1  annotator_2
# ...

# %%
target_df = master_assignements_df[(master_assignements_df['annotator_1'] == 1) & (master_assignements_df['annotator_2'] == 2)]
target_df.head(50)
# Out:
#      article_id  comment_id    user_id  provider provider_name annotator_pair  \
# 0    5392511582  3068652864     617031         4   motherjones         (1, 2)
# 1    5392511582  3060312757  183440977         4   motherjones         (1, 2)
# 2    5392511582  3059121940   15651552         4   motherjones         (1, 2)
# 3    5392511582  3061231944  235747564         4   motherjones         (1, 2)
# 4    5392511582  3066560379   35998968         4   motherjones         (1, 2)
# 5    5392511582  3059802377  166680896         4   motherjones         (1, 2)
# 6    5392511582  3059057400   22343219         4   motherjones         (1, 2)
# 7    5392511582  3059098451    4811341         4   motherjones         (1, 2)
# 8    5392511582  3067003059   23375444         4   motherjones         (1, 2)
# 9    5392511582  3061329823   42040275         4   motherjones         (1, 2)
# 10   5392511582  3059722173   48417445         4   motherjones         (1, 2)
# ...

# %%
target_comment_id = 3068652864

# %%
first_row = results_df_first[results_df_first["comment_id"] == target_comment_id]
first_row
# Out:
#    provider_name  article_id  comment_id  \
# 22   motherjones  5392511582  3068652864
#
#                                                 Notes Barack Obama  \
# 22  against regan; when they say the wealth is not...          NaN
#
#    Donald Trump Joe Biden (democrat | liberal)  (republican | conservative)  \
# 22          NaN       NaN                   NaN                         E -
#
#    Progressives  ... Supreme court Free trade | globalization   \
# 22          NaN  ...           NaN                         NaN
#
#    Traditional family values Palestine Mexico / mexicans  \
# 22                       NaN       NaN               NaN
#
#    EU | Europe | European country  Billionaires Big pharma   \
# 22                            NaN           NaN         NaN
#
#    Big tech is too powerful COMPLETED
# 22                      NaN      True
#
# [1 rows x 67 columns]

# %%
second_row = results_df_second[results_df_second["comment_id"] == target_comment_id]
second_row
# Out:
#    provider_name  article_id  comment_id Notes Barack Obama Donald Trump  \
# 22   motherjones  5392511582  3068652864   NaN          NaN          NaN
#
#    Joe Biden (democrat | liberal)  (republican | conservative) Progressives  \
# 22       NaN                   I +                         E -          I +
#
#     ... Supreme court Free trade | globalization  Traditional family values  \
# 22  ...           NaN                         NaN                       NaN
#
#    Palestine Mexico / mexicans EU | Europe | European country Billionaires  \
# 22       NaN               NaN                            NaN          E -
#
#    Big pharma  Big tech is too powerful  COMPLETED
# 22         NaN                      NaN       True
#
# [1 rows x 67 columns]

# %%
first_row != second_row
# Out:
#     provider_name  article_id  comment_id  Notes  Barack Obama  Donald Trump  \
# 22          False       False       False   True          True          True
#
#     Joe Biden  (democrat | liberal)   (republican | conservative)  \
# 22       True                   True                        False
#
#     Progressives  ...  Supreme court  Free trade | globalization   \
# 22          True  ...           True                         True
#
#     Traditional family values  Palestine  Mexico / mexicans  \
# 22                       True       True               True
#
#     EU | Europe | European country  Billionaires  Big pharma   \
# 22                            True          True         True
#
#     Big tech is too powerful  COMPLETED
# 22                      True      False
#
# [1 rows x 67 columns]

# %%
# filter not NaN 
# then compare
first_row.eq(second_row) | (first_row.isna() & second_row.isna())
# Out:
#     provider_name  article_id  comment_id  Notes  Barack Obama  Donald Trump  \
# 22           True        True        True  False          True          True
#
#     Joe Biden  (democrat | liberal)   (republican | conservative)  \
# 22       True                  False                         True
#
#     Progressives  ...  Supreme court  Free trade | globalization   \
# 22         False  ...           True                         True
#
#     Traditional family values  Palestine  Mexico / mexicans  \
# 22                       True       True               True
#
#     EU | Europe | European country  Billionaires  Big pharma   \
# 22                            True         False         True
#
#     Big tech is too powerful  COMPLETED
# 22                      True       True
#
# [1 rows x 67 columns]
