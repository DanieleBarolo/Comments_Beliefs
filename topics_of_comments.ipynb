# %%
import pandas as pd

# %%
breitbart_comments = pd.read_csv('Comments_topics/topics_global.csv')
breitbart_comments.head(15)
# Out:
#     Topic   Count                                      Name  \
# 0       0  903704                 -1_trump_like_just_people
# 1       1  109362                   0_youre_apple_stupid_im
# 2       2  104974          1_obama_trump_democrats_election
# 3       3   63067                 2_tax_taxes_economy_money
# 4       4   56491       3_school_students_schools_education
# 5       5   51792             4_shes_hillary_pelosi_clinton
# 6       6   49381               5_black_white_racist_blacks
# 7       7   30175              6_muslims_islam_muslim_saudi
# 8       8   26699               7_god_church_jesus_catholic
# 9       9   25832                      8_news_fox_cnn_media
# 10     10   25074             9_california_texas_city_state
# 11     11   24313                10_fbi_mueller_comey_flynn
# 12     12   23737                 11_prison_jury_jail_crime
# 13     13   22253  12_insurance_obamacare_health_healthcare
# 14     14   22241          13_climate_warming_energy_global
#
# ...

# %%
from pprint import pprint
for i in range(1, 20):
    print(f"count: {breitbart_comments.loc[i, 'Count']}")
    print(breitbart_comments.loc[i, 'Representation'])
    pprint(breitbart_comments.loc[i, 'Representative_Docs'])
    print('-'*50)
# Out:
# count: 109362
# ['youre', 'apple', 'stupid', 'im', 'dont', 'just', 'know', 'thats', 'like', 'lol']
# ('[\'hope that becomes reality really like the guy\', "you\'re also saying '
#  "that people who do know math are 'stupid' for various values of 'stupid' i "
#  "guess but since the conversation is 'closed' according to you you will "
#  'actually live up to your words and not post any more right", \'just read his '
#  'words son never asked for his help it does not mean anything for example '
#  'maybe the wife of son asked his help just investigate it nothing to fear if '
#  "he didnt do anything wrong']")
# --------------------------------------------------
# count: 104974
# ['obama', 'trump', 'democrats', 'election', 'republicans', 'president', 'gop', 'vote', 'party', 'republican']
# ('["easy he got the black vote bernie didn\'t the early states also happen to '
#  "be the states with highest percentage of black voters i know i can't right "
# ...

# %%
breitbart_comments.Count.sum()
# Out:
# 2000000
